# %%
# def career_guidance():
    print("===== AI-Based Career Guidance System =====")

    name = input("Enter your name: ")

    print("\nSelect your interest area:")
    print("1. Programming")
    print("2. Electronics")
    print("3. Networking")
    print("4. Management")
    print("5. Government Jobs")

    choice = int(input("Enter your choice (1-5): "))
    marks = int(input("Enter your average marks percentage: "))

    print("\nCareer Recommendation for", name)

    if choice == 1:
        if marks >= 70:
            print("Recommended Career: Software Developer / Data Analyst")
        else:
            print("Recommended Career: Software Tester / Support Engineer")

    elif choice == 2:
        if marks >= 65:
            print("Recommended Career: Electronics Engineer / Embedded Engineer")
        else:
            print("Recommended Career: Technician / Diploma Courses")

    elif choice == 3:
        if marks >= 60:
            print("Recommended Career: Network Engineer / System Administrator")
        else:
            print("Recommended Career: Network Support Executive")

    elif choice == 4:
        if marks >= 55:
            print("Recommended Career: MBA / Business Analyst")
        else:
            print("Recommended Career: Sales Executive / HR Assistant")

    elif choice == 5:
        if marks >= 50:
            print("Recommended Career: Government Exams (SSC, Banking, UPSC)")
        else:
            print("Recommended Career: Skill Development Programs")

    else:
        print("Invalid choice. Please try again.")

    print("\nThank you for using the Career Guidance System!")


career_guidance()
# Out:
# ===== AI-Based Career Guidance System =====
# Enter your name:  Dishaa Chandgadkar
# Select your interest area:
# 1. Programming
# 2. Electronics
# 3. Networking
# 4. Management
# 5. Government Jobs
# Enter your choice (1-5):  1
# Enter your average marks percentage:  50
# Career Recommendation for Dishaa Chandgadkar
# Recommended Career: Software Tester / Support Engineer
#
# Thank you for using the Career Guidance System!
